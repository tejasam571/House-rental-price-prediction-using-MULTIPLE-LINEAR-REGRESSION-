# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'house.ui'
#
# Created by: PyQt5 UI code generator 5.15.9
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1296, 729)
        Form.setStyleSheet("")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(140, 10, 1011, 61))
        self.label.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(170, 255, 127);\n"
"font: 14pt \"Lucida Fax\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(80, 110, 201, 41))
        self.label_2.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(80, 180, 201, 41))
        self.label_3.setStyleSheet("background-color: rgb(255, 170, 255);\n"
"color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(80, 250, 201, 41))
        self.label_4.setStyleSheet("font: 10pt \"Lucida Calligraphy\";\n"
"color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(80, 320, 201, 41))
        self.label_5.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(720, 110, 201, 41))
        self.label_6.setStyleSheet("color:rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(720, 180, 201, 41))
        self.label_7.setStyleSheet("color: rgb(0, 0, 0);\n"
"background:rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(720, 320, 201, 41))
        self.label_8.setStyleSheet("color:rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_8.setObjectName("label_8")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(450, 530, 421, 51))
        self.pushButton.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 14pt \"Lucida Fax\";\n"
"background-color: rgb(170, 255, 127);")
        self.pushButton.setObjectName("pushButton")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(120, 630, 191, 61))
        self.label_9.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 12pt \"Lucida Calligraphy\";\n"
"background-color: rgb(255, 170, 255);")
        self.label_9.setObjectName("label_9")
        self.city = QtWidgets.QLineEdit(Form)
        self.city.setGeometry(QtCore.QRect(320, 110, 271, 41))
        self.city.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.city.setObjectName("city")
        self.area = QtWidgets.QLineEdit(Form)
        self.area.setGeometry(QtCore.QRect(320, 180, 271, 41))
        self.area.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.area.setObjectName("area")
        self.rooms = QtWidgets.QLineEdit(Form)
        self.rooms.setGeometry(QtCore.QRect(320, 250, 271, 41))
        self.rooms.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.rooms.setObjectName("rooms")
        self.parking = QtWidgets.QLineEdit(Form)
        self.parking.setGeometry(QtCore.QRect(320, 320, 271, 41))
        self.parking.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.parking.setObjectName("parking")
        self.floor = QtWidgets.QLineEdit(Form)
        self.floor.setGeometry(QtCore.QRect(960, 110, 271, 41))
        self.floor.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.floor.setObjectName("floor")
        self.animal = QtWidgets.QLineEdit(Form)
        self.animal.setGeometry(QtCore.QRect(960, 180, 271, 41))
        self.animal.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.animal.setObjectName("animal")
        self.bathroom = QtWidgets.QLineEdit(Form)
        self.bathroom.setGeometry(QtCore.QRect(960, 320, 271, 41))
        self.bathroom.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.bathroom.setObjectName("bathroom")
        self.result = QtWidgets.QLineEdit(Form)
        self.result.setGeometry(QtCore.QRect(370, 630, 371, 61))
        self.result.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 12pt \"MS Shell Dlg 2\";")
        self.result.setObjectName("result")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(720, 250, 201, 41))
        self.label_10.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_10.setObjectName("label_10")
        self.furniture = QtWidgets.QLineEdit(Form)
        self.furniture.setGeometry(QtCore.QRect(960, 250, 271, 41))
        self.furniture.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.furniture.setObjectName("furniture")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(80, 390, 201, 41))
        self.label_11.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_11.setObjectName("label_11")
        self.hoa = QtWidgets.QLineEdit(Form)
        self.hoa.setGeometry(QtCore.QRect(320, 390, 271, 41))
        self.hoa.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.hoa.setObjectName("hoa")
        self.rent = QtWidgets.QLineEdit(Form)
        self.rent.setGeometry(QtCore.QRect(960, 390, 271, 41))
        self.rent.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.rent.setObjectName("rent")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(720, 390, 201, 41))
        self.label_12.setStyleSheet("color:rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(80, 460, 201, 41))
        self.label_13.setStyleSheet("color:rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_13.setObjectName("label_13")
        self.fire = QtWidgets.QLineEdit(Form)
        self.fire.setGeometry(QtCore.QRect(320, 460, 271, 41))
        self.fire.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.fire.setObjectName("fire")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(720, 460, 201, 41))
        self.label_14.setStyleSheet("color:rgb(0, 0, 0);\n"
"background-color: rgb(255, 170, 255);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.label_14.setObjectName("label_14")
        self.tax = QtWidgets.QLineEdit(Form)
        self.tax.setGeometry(QtCore.QRect(960, 460, 271, 41))
        self.tax.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 10pt \"Lucida Calligraphy\";")
        self.tax.setObjectName("tax")
        self.pushButton.clicked.connect(self.predict)
        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    def predict(self):
            city=self.city.text()
            area=self.area.text()
            rooms=self.rooms.text()
            bathroom=self.bathroom.text()
            parkingspaces=self.parking.text()
            floor=self.floor.text()
            animal=self.animal.text()
            furniture=self.furniture.text()
            hoa=self.hoa.text()
            rent=self.rent.text()
            tax=self.tax.text()
            fire=self.fire.text()
          
            import pandas as pd
            path="C:\\Users\\TEJAS A M\\OneDrive\\Desktop\\INTERNSHIP\\houses_to_rent_v2.csv"
            data=pd.read_csv(path)
            print(data)
            print(data.info())
            print(data.shape)
            print(data.isnull().sum())

            data['floor']=data['floor'].fillna(data['floor'].mode()[0])
           
            from sklearn.preprocessing import LabelEncoder

            le =LabelEncoder()
            data['city'] =  le.fit_transform(data['city'])
            data['animal'] =  le.fit_transform(data['animal'])
            data['furniture'] = le.fit_transform(data['furniture'])
            data['floor']=le.fit_transform(data['floor'])
            print(data)


            inputs=data.drop(["total (R$)"],axis=1)
            output=data.drop(["city","area","rooms","bathroom","parking spaces","floor","animal","furniture","hoa (R$)","rent amount (R$)","property tax (R$)","fire insurance (R$)"],axis=1)
            print(inputs)
            print(output)

            from sklearn import linear_model

            model=linear_model.LinearRegression()
            model.fit(inputs,output)
            res=model.predict([[float(city),int(area),int(rooms),int(bathroom),int(parkingspaces),float(floor),int(animal),int(furniture),int(hoa),int(rent),int(tax),int(fire)]])
            self.result.setText(str(res))
            print("PREDICTED VALUE:",res)

            acc=model.score(inputs,output)
            print("ACCURACY:",acc*100) 
     
    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "         HOUSE RENT PREDICTION USING MULTILINEAR REGRESSION    "))
        self.label_2.setText(_translate("Form", "    CITY :"))
        self.label_3.setText(_translate("Form", "  AREA :"))
        self.label_4.setText(_translate("Form", " ROOMS :"))
        self.label_5.setText(_translate("Form", " PARKING :"))
        self.label_6.setText(_translate("Form", "FLOOR :"))
        self.label_7.setText(_translate("Form", "ANIMAL :"))
        self.label_8.setText(_translate("Form", "BATHROOM :"))
        self.pushButton.setText(_translate("Form", "PREDICT"))
        self.label_9.setText(_translate("Form", "  RESULT : "))
        self.city.setPlaceholderText(_translate("Form", "ENTER CITY"))

        self.area.setPlaceholderText(_translate("Form", "ENTER AREA"))
        self.rooms.setPlaceholderText(_translate("Form", "NO OF ROOMS"))
        self.parking.setPlaceholderText(_translate("Form", "PARKING SPACE"))
        self.floor.setPlaceholderText(_translate("Form", "FLOOR NUMBER"))
        self.animal.setPlaceholderText(_translate("Form", "ACCEPT OR NOT"))
        self.bathroom.setPlaceholderText(_translate("Form", "NO OF BATHROOM"))
        self.result.setPlaceholderText(_translate("Form", "PREDICTED VALUE"))
        self.label_10.setText(_translate("Form", "FURNITURE :"))
        self.furniture.setPlaceholderText(_translate("Form", "FURNISHED OR NOT"))
        self.label_11.setText(_translate("Form", " HOA (R$) :"))
        self.hoa.setPlaceholderText(_translate("Form", "HOA IN DOLLAR"))
        self.rent.setPlaceholderText(_translate("Form", "AMOUNT"))
        self.label_12.setText(_translate("Form", "RENT AMOUNT:"))
        self.label_13.setText(_translate("Form", "FIRE INSURANCE :"))
        self.fire.setPlaceholderText(_translate("Form", "INSURANCE"))
        self.label_14.setText(_translate("Form", "PROPERTY TAX:"))
        self.tax.setPlaceholderText(_translate("Form", "PROPERTY TAX"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           São Paulo    70      2         1               1     7      acept
# 1           São Paulo   320      4         4               0    20      acept
# 2        Porto Alegre    80      1         1               1     6      acept
# 3        Porto Alegre    51      2         1               0     2      acept
# 4           São Paulo    25      1         1               0     1  not acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10687    Porto Alegre    63      2         1               1     5  not acept
# 10688       São Paulo   285      4         4               4    17      acept
# 10689  Rio de Janeiro    70      3         3               0     8  not acept
# 10690  Rio de Janeiro   120      2         2               2     8      acept
# 10691       São Paulo    80      2         1               0     -      acept
#
# ...
